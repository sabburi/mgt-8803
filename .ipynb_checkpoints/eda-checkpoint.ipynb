# %%
import pandas as pd
import numpy as np

# %%
pd.
# Out:
# City is: Surrey

# %%
# Out:
# Unmatched token:  "Almaly
# Unmatched token:  "Cantonia"
# Unmatched token:  "Les
# Unmatched token:  "Touchstone";
# Unmatched token:  "VILLA"
# Unmatched token:  "Whingate"
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  -DONG;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  -2;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  -802;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  -1;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  ;
# Unmatched token:  [OMG
# Unmatched token:  ;
# Unmatched token:  ;
# ...

# %%
city_list
# Out:
# [None,
#  None,
#  'Surrey',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
